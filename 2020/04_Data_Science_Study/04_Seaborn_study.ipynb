# %% [markdown]
# # Seaborn (complementar do Matplotlib)
#
# - Utiliza-se dos recursos da matplotlib. <br>
# - Relaciona-se fácil com o Pandas <br>
# - Seaborn, which provides a high-level interface to draw statistical graphics.<br>
#
# fonte: https://www.datacamp.com/community/tutorials/seaborn-python-tutorial?utm_source=adwords_ppc&utm_campaignid=1455363063&utm_adgroupid=65083631748&utm_device=c&utm_keyword=&utm_matchtype=b&utm_network=g&utm_adpostion=&utm_creative=332602034358&utm_targetid=dsa-473406580275&utm_loc_interest_ms=&utm_loc_physical_ms=1001778&gclid=Cj0KCQjwmdzzBRC7ARIsANdqRRltSPqpRLhBTRHAR81XbU7LmiIo0uNPnLj5MONHOZiwO-NP9nJ6wI0aAozWEALw_wcB#sm

# %% [markdown]
# ### Parte 1 - Distribution Plots

# %%
import seaborn as sns
import pandas as pd

# %%
# %matplotlib inline

# %%
tips = sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# Essa função abaixo é a soma de todas as gaussiana
#perceba que no fim temos um pequeno pico,
#pois o número 50 aparece 2x

# %%
sns.distplot(tips['total_bill'])

# %%
tips['total_bill'].mean()
# Out:
# 19.78594262295082

# %%
sns.distplot(tips['total_bill'],kde = False)

# %%
sns.distplot(tips['total_bill'],bins = 40)
#quantidade de histogramas

# %%
sns.jointplot(x='total_bill',y='tip',data=tips)

# %%
sns.jointplot(x='total_bill',y='tip',data=tips, kind ='hex' )

# %%
sns.jointplot(x='total_bill',y='tip',data=tips, kind ='reg' )

# %%
sns.jointplot(x='total_bill',y='tip',data=tips, kind ='kde' )

# %%
data1 = {
    'idade':[1,2.5,6,11,5.5,1.5,2,20,30],
    'gasto':[40,30,20,10,1,1,10,10,15]
}

df = pd.DataFrame(data = data1)
sns.distplot(df['idade'])

# %%
sns.jointplot(x='gasto',y='idade',data=data1, kind ='kde' )

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# 5         25.29  4.71    Male     No   Sun  Dinner     4
# 6          8.77  2.00    Male     No   Sun  Dinner     2
# 7         26.88  3.12    Male     No   Sun  Dinner     4
# 8         15.04  1.96    Male     No   Sun  Dinner     2
# 9         14.78  3.23    Male     No   Sun  Dinner     2
# 10        10.27  1.71    Male     No   Sun  Dinner     2
# 11        35.26  5.00  Female     No   Sun  Dinner     4
# 12        15.42  1.57    Male     No   Sun  Dinner     2
# 13        18.43  3.00    Male     No   Sun  Dinner     4
# 14        14.83  3.02  Female     No   Sun  Dinner     2
# ...

# %%
tips['total_bill']
# Out:
# 50.81

# %%
sns.pairplot(tips)

# %%
sns.pairplot(tips, hue = 'sex')

# %%
sns.pairplot(tips, hue = 'time')

# %%
sns.pairplot(tips, hue = 'day',palette = 'coolwarm' )

# %%
sns.rugplot(tips['total_bill'])

# %%
sns.distplot(tips['total_bill'],kde = False)

# %%
#help(pd.read_csv) #usei pra ver como separar por Tab... pois o padrão é ','
df1 = pd.read_csv('./dados_panda/multicamada.txt',sep = '\t')
df1
# Out:
#       Freq (GHZ)  RL(dB)
# 0          12.40   -8.14
# 1          12.40   -8.04
# 2          12.41   -8.25
# 3          12.41   -8.31
# 4          12.41   -8.34
# 5          12.42   -8.12
# 6          12.42   -8.26
# 7          12.42   -8.26
# 8          12.43   -8.33
# 9          12.43   -8.07
# 10         12.44   -8.14
# 11         12.44   -8.23
# 12         12.44   -8.36
# 13         12.45   -8.30
# 14         12.45   -8.30
# 15         12.45   -8.14
# 16         12.46   -8.34
# 17         12.46   -8.11
# 18         12.46   -8.33
# 19         12.47   -8.19
# 20         12.47   -8.21
# 21         12.47   -8.18
# 22         12.48   -8.18
# 23         12.48   -8.28
# 24         12.48   -8.12
# 25         12.49   -8.14
# 26         12.49   -8.15
# 27         12.49   -8.13
# 28         12.50   -8.33
# 29         12.50   -8.14
# ...          ...     ...
# 1571       17.90  -11.43
# 1572       17.90  -11.40
# 1573       17.91  -11.67
# 1574       17.91  -11.59
# 1575       17.91  -11.61
# ...

# %%
sns.distplot(df1['RL(dB)'], )

# %%
sns.jointplot(x='Freq (GHZ)',y='RL(dB)',data=df1, kind ='kde' )

# %% [markdown]
# ### Parte 2 - Categorical Plots

# %%
import seaborn as sns
import numpy as np
# %matplotlib inline
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.barplot(x='sex',y='total_bill',data= tips)

# %%
#func desvio padrao
sns.barplot(x='sex',y='total_bill',data= tips,estimator = np.std)

# %%
sns.countplot(x='sex',data = tips)

# %%
sns.countplot(x='day',data = tips)

# %%
sns.boxplot(x='day', y ='total_bill', data = tips)

# %%
sns.boxplot(x='day', y ='total_bill', data = tips, hue = 'smoker')

# %%
sns.violinplot(x='day',y = 'total_bill',data = tips)

# %%
sns.violinplot(x='day',y = 'total_bill',data = tips,hue = 'sex')

# %%
sns.violinplot(x='day',y = 'total_bill',data = tips,hue = 'sex', split = True)

# %%
sns.stripplot(x = 'day', y = 'total_bill', data = tips)

# %%
sns.stripplot(x = 'day', y = 'total_bill', data = tips, jitter = True)

# %%
sns.stripplot(x = 'day', y = 'total_bill', data = tips, jitter = False)

# %%
sns.stripplot(x = 'day', y = 'total_bill', data = tips, jitter = True, hue = 'sex')

# %%
sns.stripplot(x = 'day', y = 'total_bill', data = tips, jitter = True, hue = 'sex', split = True)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:2775: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)

# %%
sns.swarmplot(x = 'day', y = 'total_bill', data = tips)

# %%
sns.violinplot(x = 'day' , y = 'total_bill', data = tips)
sns.swarmplot(x = 'day', y = 'total_bill', data = tips, color = 'black')

# %%
# Mudaram o nome da funcao de factorplot para catplot
#sns.factorplot(x = 'day', y = 'total_bill' , data = tips, kind = 'bar')
sns.catplot(x = 'day', y = 'total_bill' , data = tips, kind = 'bar')

# %%
sns.catplot(x = 'day', y = 'total_bill' , data = tips, kind = 'violin')

# %% [markdown]
# ### Parte 3 - Matrix Plots

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
#Dados de correlação
tc = tips.corr()

# %%
sns.heatmap(tc)

# %%
#argumento
sns.heatmap(tc, annot = True)

# %%
sns.heatmap(tc, annot = True, cmap = 'coolwarm')

# %%
flights = sns.load_dataset('flights')
flights.head()
# Out:
#    year     month  passengers
# 0  1949   January         112
# 1  1949  February         118
# 2  1949     March         132
# 3  1949     April         129
# 4  1949       May         121

# %%
fp = flights.pivot_table(index = 'month', columns = 'year', values = 'passengers')
fp.head()
# Out:
# year      1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  \
# month
# January    112   115   145   171   196   204   242   284   315   340   360
# February   118   126   150   180   196   188   233   277   301   318   342
# March      132   141   178   193   236   235   267   317   356   362   406
# April      129   135   163   181   235   227   269   313   348   348   396
# May        121   125   172   183   229   234   270   318   355   363   420
#
# year      1960
# month
# January    417
# February   391
# March      419
# April      461
# May        472

# %%
sns.heatmap(fp, cmap = 'magma')

# %%
sns.heatmap(fp, cmap = 'magma', linecolor = 'white', linewidth = '1')

# %%
sns.clustermap(fp, cmap = 'coolwarm')
#Repare que ele reorganiza

# %%
sns.clustermap(fp, cmap = 'coolwarm', standard_scale=1)
#Repare que ele reorganiza

# %% [markdown]
# ### Parte 3 - Grids
